# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Datset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate random data
np.random.seed(42)

# generate random data
area = np.random.uniform(low=500, high=2000, size=300)
noise = np.random.normal(loc=0, scale=2000, size=300)
price = 5000 + 10*area + noise

# create dataframe

# Create dataframe
df = pd.DataFrame({'area': area, 'price': price})
df
# Out:
#             area         price
# 0    1061.810178  15709.245463
# 1    1926.071460  22957.513901
# 2    1597.990913  25267.797306
# 3    1397.987726  20247.715308
# 4     734.027961   8289.994433
# ..           ...           ...
# 295  1283.364890  17929.818794
# 296  1654.990330  22069.348300
# 297   823.731541  11428.682162
# 298  1434.335714  20620.542055
# 299   628.021197   7957.171850
#
# [300 rows x 2 columns]

# %% [markdown]
# ## Summarize Dataset

# %%
df.shape
# Out:
# (300, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    300 non-null    float64
#  1   price   300 non-null    float64
# dtypes: float64(2)
# memory usage: 4.8 KB

# %%
df.describe()
# Out:
#               area         price
# count   300.000000    300.000000
# mean   1242.806899  17399.642306
# std     441.510809   4977.780679
# min     507.592376   7377.752858
# 25%     858.621206  13471.032855
# 50%    1267.576593  17558.389492
# 75%    1635.289424  21254.885652
# max    1985.080775  28358.550873

# %% [markdown]
# ## Visualize Dataset

# %%
plt.xlabel("Area")
plt.ylabel("Price")
plt.scatter(df.area,df.price,color="red",marker="*")

# %% [markdown]
# ## Segregate Dataset into Input X and Output Y

# %%
X = df.iloc[:,:-1].values
X
# Out:
# array([[1061.81017827],
#        [1926.07145961],
#        [1597.99091272],
#        [1397.9877263 ],
#        [ 734.02796066],
#        [ 733.9917805 ],
#        [ 587.12541825],
#        [1799.26421866],
#        [1401.67251761],
#        [1562.10886669],
#        [ 530.87674144],
#        [1954.86477824],
#        [1748.6639612 ],
#        [ 818.50866602],
#        [ 772.73745081],
#        [ 775.10676478],
#        [ 956.36336444],
#        [1287.13464745],
#        [1147.91752796],
#        [ 936.8437103 ],
#        [1417.77934208],
#        [ 709.24079098],
#        [ 938.2169728 ],
#        [1049.54276494],
#        [1184.10497633],
#        [1677.76394209],
#        [ 799.51067324],
#        [1271.35165762],
#        [1388.62185329],
#        [ 569.67561908],
#        [1411.31727785],
#        [ 755.78618553],
#        [ 597.57738948],
#        [1923.32830588],
#        [1948.44804961],
#        [1712.59602217],
#        [ 956.92065376],
#        [ 646.50817101],
# ...

# %%
Y = df.price
Y
# Out:
# 0      15709.245463
# 1      22957.513901
# 2      25267.797306
# 3      20247.715308
# 4       8289.994433
#            ...
# 295    17929.818794
# 296    22069.348300
# 297    11428.682162
# 298    20620.542055
# 299     7957.171850
# Name: price, Length: 300, dtype: float64

# %% [markdown]
# ## Training Dataset Using Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %% [markdown]
# ## Splitting Into Train and Test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=0)
X_train
# Out:
# array([[1914.36455587],
#        [ 555.33042103],
#        [1035.12999004],
#        [1040.28596212],
#        [ 553.9134107 ],
#        [ 897.80355152],
#        [1776.70500728],
#        [ 741.83193088],
#        [1417.77934208],
#        [ 967.56661413],
#        [1508.20332111],
#        [1838.06983277],
#        [1869.86082883],
#        [1271.35165762],
#        [ 927.26074157],
#        [ 645.76474066],
#        [ 646.50817101],
#        [1141.31152754],
#        [1845.82363693],
#        [ 984.80439803],
#        [1838.83849773],
#        [1051.67469908],
#        [1816.05960789],
#        [1568.26883202],
#        [1468.20844386],
#        [1656.90552003],
#        [1477.94188925],
#        [ 865.98446507],
#        [1335.20189369],
#        [ 536.47394965],
#        [1063.37442896],
#        [ 888.1699724 ],
#        [1800.60847787],
#        [ 862.77843635],
#        [ 717.34230814],
#        [ 856.45631599],
#        [1454.6156169 ],
#        [1396.84996822],
# ...

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([10.11466672])

# %%
model.intercept_
# Out:
# 4868.598414086242

# %% [markdown]
# ## Predicting For Test Data

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([10002.72612269, 17961.79038638, 22555.75158029, 18548.30994424,
#        12613.05501332, 17797.02312385, 21984.80892861, 11465.4580281 ,
#        24180.00978344, 13397.25755604, 10388.68156654, 12708.54500932,
#        13839.42216706, 24545.97413622, 14358.35040149, 20650.37144559,
#        22205.55928327, 11740.41568046, 19501.56705274, 11295.80817017,
#        11338.48697227, 17641.96633635, 13384.16407522, 17674.98988486,
#        11347.16535665, 22119.24458264, 15069.69178719, 16989.98493791,
#        12888.15839758, 17849.40655256, 21468.56258636, 12064.03412399,
#        19046.04877504, 14750.68051811, 22810.34941933, 23706.14186159,
#        20408.83918604, 23955.38341745, 11220.82351742, 12292.68064633,
#        15504.91596354, 17090.37665185, 19382.61099875, 24576.50104978,
#        23912.60773449, 24669.80960347, 14185.81007602, 14188.27017405,
#        23067.55632027, 19977.71991966, 22298.11262532, 13328.545752  ,
# ...

# %% [markdown]
# ## Evaluating Performance

# %%
# Compute R-squared value
from sklearn.metrics import r2_score

# Calculate the R² value between the predicted and actual target values
r2 = r2_score(y_test, y_pred)
print('R²:', r2)
# Out:
# R²: 0.8578652186389979

# %% [markdown]
# ## Predicted Price For Land Sq.Feet of Custom Values

# %%
x = 4785
LandAreainSqFt = [[x]]
PredictedModelResult = model.predict(LandAreainSqFt)
print(PredictedModelResult)
# Out:
# [53267.27865119]
